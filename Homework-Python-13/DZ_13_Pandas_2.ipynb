# %% [markdown]
# Задание 1
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
#
# если источник traffic_source равен yandex или google, то в source_type ставится organic
#
# для источников paid и email из России - ставим ad
#
# для источников paid и email не из России - ставим other
#
# все остальные варианты берем из traffic_source без изменений

# %%
#Импортируем библиотеку
import pandas as pd
# Открываем файл
log = pd.read_csv('visit_log.csv', sep=';')
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
# если источник traffic_source равен yandex или google, то в source_type ставится organic
log.loc[(log.traffic_source == 'yandex') | (log.traffic_source == 'google'), 'source_type'] = 'organic'

# %%
# для источников paid и email из России - ставим ad
log.loc[((log.traffic_source == 'paid') | (log.traffic_source == 'email')) & (log.region=='Russia'), 'source_type'] = 'ad'

# %%
#для источников paid и email не из России - ставим other
log.loc[((log.traffic_source == 'paid')| (log.traffic_source == 'email'))&(log.region!='Russia'), 'source_type'] = 'other'

# %%
#все остальные варианты берем из traffic_source без изменений
log.loc[log.source_type.isnull(), 'source_type']=log['traffic_source']

# %%
log.head(10)
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
# 5  1549980742  8855508aad  https://host.ru/df646c3676cc259fa0  Russia
# 6  1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15  Russia
# 7  1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e  Russia
# 8  1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867   China
# 9  1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic
# 5  fc43898e47         yandex     organic
# 6  13fc55e781           paid          ad
# 7  cb5082b6f6         direct      direct
# 8  45664f7af2         direct      direct
# 9  6f9de8c8b6          email          ad

# %% [markdown]
# Задание 2
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
#
# Прочитайте содержимое файла с датафрейм
#
# Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
#Импортируем библиотеку
import re

# %%
# Открываем файл
urls_news=pd.read_csv('URLs.txt')

# %%
urls_news.head()
# Out:
#                                                  url
# 0                                            /world/
# 1                                           /latest/
# 2                                      /?updated=top
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %%
#Отфильтровываем страницы с текстом новостей согласно шаблону: /, затем 8 цифр, затем дефис.
urls_news[urls_news.url.str.contains('/[0-9]{8}-', regex=True)].head()
# Out:
#                                                  url
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5  /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6  /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %% [markdown]
# Домашнее задание 3
#
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
#Установка библиотеки
pip install pymystem3
# Out:
# Requirement already satisfied: pymystem3 in c:\users\kaa\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: requests in c:\users\kaa\anaconda3\lib\site-packages (from pymystem3) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaa\anaconda3\lib\site-packages (from requests->pymystem3) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kaa\anaconda3\lib\site-packages (from requests->pymystem3) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kaa\anaconda3\lib\site-packages (from requests->pymystem3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kaa\anaconda3\lib\site-packages (from requests->pymystem3) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymystem3 import Mystem

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})

# %%
#Задаем функцию, которая вычисляет леммы поисковых запросов из столбца keyword. 
def lemmas_function(row):
    m=Mystem()
    lemma = m.lemmatize(row['keyword'])
    string = ' '.join(lemma)
    return string

# %%
#Применяем функцию к датафрейму
data['lemmas']=data.apply(lemmas_function, axis=1)

# %%
data
# Out:
#                  keyword   shows                        lemmas
# 0    курс гривны к рублю  125076  курс   гривна   к   рубль \n
# 1        доллары в рубли  114173         доллар   в   рубль \n
# 2  100 долларов в рублях   97534   100   доллар   в   рубль \n
# 3             курс рубля   53546               курс   рубль \n
